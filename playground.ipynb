# %%
# Your query
query = 'What biological pathways link intracranial aneurysm rupture risk to inflammation and hemodynamics?'

# %%
# PubMed search with smart query builder (UMLS/MeSH)
import sys, os

# Ensure project root is on path
sys.path.insert(0, os.path.abspath("."))

from api.pubmed_client import PubMedAPIClient

pubmed = PubMedAPIClient()

# Smart query: automatically converts user query → n-grams → UMLS → MeSH → PubMed query
# Set use_smart_query=False to use raw query directly
# Set return_query=True to see the generated PubMed query
response = pubmed.search(query, max_results=10, use_smart_query=True, full_text_only=False, return_query=True)

# Display the generated query
print("=" * 80)
print("GENERATED PUBMED QUERY:")
print("=" * 80)
if response.get('original_query') and response['original_query'] != response['query']:
    print(f"Original query: {response['original_query']}")
    print()
print(f"PubMed query: {response['query']}")
print("=" * 80)
print()

# Display results
results = response['results']
print(f"Returned {len(results)} results\n")
for r in results:
    print(f"PMID {r['pmid']}: {r['title']}")
# Out:
# ================================================================================
# GENERATED PUBMED QUERY:
# ================================================================================
# Original query: What biological pathways link intracranial aneurysm rupture risk to inflammation and hemodynamics?
#
# PubMed query: ("intracranial"[Title/Abstract] OR "Intracranial Aneurysm"[MeSH Terms] OR "intracranial aneurysm"[Title/Abstract]) AND ("Aneurysm"[MeSH Terms] OR "aneurysm"[Title/Abstract] OR "Aneurysm, Ruptured"[MeSH Terms] OR "aneurysm, ruptured"[Title/Abstract]) AND ("Rupture"[MeSH Terms] OR "rupture"[Title/Abstract]) AND ("Inflammation"[MeSH Terms] OR "inflammation"[Title/Abstract]) AND ("Hemodynamics"[MeSH Terms] OR "hemodynamics"[Title/Abstract])
# ================================================================================
#
# Returned 10 results
#
# PMID 29709752: Hemodynamic Stress, Inflammation, and Intracranial Aneurysm Development and Rupture: A Systematic Review.
# PMID 34847937: Underlying mechanism of hemodynamics and intracranial aneurysm.
# PMID 41155344: Molecular Targets for Intracranial Aneurysm Treatment.
# PMID 31389675: Endothelial dysfunction in cerebral aneurysms.
# PMID 31323409: Aneurysm Formation, Growth, and Rupture: The Biology and Physics of Cerebral Aneurysms.
# PMID 40757944: Separate aneurysmal neck is essential for analyzing hemodynamics and predicting instability of intracranial aneurysms.
# PMID 39443148: A Review of Intracranial Aneurysm Imaging Modalities, from CT to State-of-the-Art MR.
# PMID 41303289: Mechanisms of Intracranial Aneurysm Rupture: An Integrative Review of Experimental and Clinical Evidence.
# PMID 38781806: Role of inflammatory mediators in intracranial aneurysms: A review.
# PMID 24306170: Factors affecting formation and rupture of intracranial saccular aneurysms.

# %%
# Optional: full-text-only results (PMC/fulltext signal)
fulltext_response = pubmed.search(query, max_results=10, full_text_only=True, return_query=True)

print("=" * 80)
print("GENERATED PUBMED QUERY (Full-text only):")
print("=" * 80)
if fulltext_response.get('original_query') and fulltext_response['original_query'] != fulltext_response['query']:
    print(f"Original query: {fulltext_response['original_query']}")
    print()
print(f"PubMed query: {fulltext_response['query']}")
print("=" * 80)
print()

print("\n--- Full-text-only (PMC/fulltext signal) ---")
fulltext_results = fulltext_response['results']
for r in fulltext_results:
    ft = "FT" if r.get("has_full_text") else ""
    pmc = f" ({r['pmc_id']})" if r.get("pmc_id") else ""
    print(f"PMID {r['pmid']}{pmc}: {r['title']} {ft}")
# Out:
# ================================================================================
# GENERATED PUBMED QUERY (Full-text only):
# ================================================================================
# Original query: What biological pathways link intracranial aneurysm rupture risk to inflammation and hemodynamics?
#
# PubMed query: ("intracranial"[Title/Abstract] OR "Intracranial Aneurysm"[MeSH Terms] OR "intracranial aneurysm"[Title/Abstract]) AND ("Aneurysm"[MeSH Terms] OR "aneurysm"[Title/Abstract] OR "Aneurysm, Ruptured"[MeSH Terms] OR "aneurysm, ruptured"[Title/Abstract]) AND ("Rupture"[MeSH Terms] OR "rupture"[Title/Abstract]) AND ("Inflammation"[MeSH Terms] OR "inflammation"[Title/Abstract]) AND ("Hemodynamics"[MeSH Terms] OR "hemodynamics"[Title/Abstract])
# ================================================================================
#
#
# --- Full-text-only (PMC/fulltext signal) ---
# PMID 34847937 (PMC8638472): Underlying mechanism of hemodynamics and intracranial aneurysm. FT
# PMID 41155344 (PMC12564334): Molecular Targets for Intracranial Aneurysm Treatment. FT
# PMID 40757944 (PMC12322982): Separate aneurysmal neck is essential for analyzing hemodynamics and predicting instability of intracranial aneurysms. FT
# PMID 39443148 (PMC12152792): A Review of Intracranial Aneurysm Imaging Modalities, from CT to State-of-the-Art MR. FT
# PMID 41303289 (PMC12653054): Mechanisms of Intracranial Aneurysm Rupture: An Integrative Review of Experimental and Clinical Evidence. FT
# PMID 16759441 (PMC2754184): Intracranial aneurysms: links among inflammation, hemodynamics and vascular remodeling. FT
# PMID 23316103 (PMC3532877): Cigarette smoke and inflammation: role in cerebral aneurysm formation and rupture. FT
# PMID 41323131 (PMC12662757): Intracranial Aneurysm Wall Phenotypes: Clinical, Morphological, and Hemodynamic Influences. FT
# PMID 31960286 (PMC7495996): Wall Enhancement, Hemodynamics, and Morphology in Unruptured Intracranial Aneurysms with High Rupture Risk. FT
# PMID 31002750 (PMC6618041): Impact of Intracranial Aneurysm Morphology and Rupture Status on the Particle Residence Time. FT
